# %% [markdown]
# # Evolution of Airports, Airways in the United States

# %% [markdown]
# ### Team Members

# %% [markdown]
# Anusha Ramamurthy
# Sathosh Soundararajan

# %% [markdown]
# ### Abstract

# %% [markdown]
# An article to create a time series analysis of the airline industry, visualizing the onset of different airports and airline carriers at various locations across the United States. It will also feature the performance of top airlines based on their flight on-time arrivals and departures. Further it will explore the various factors that cause delays and predict them.

# %% [markdown]
# ## Introduction

# %% [markdown]
# ### Why should we care?

# %% [markdown]
# The United States has an extensive air transportation network. In 2013 there were 86 airports in the U.S. that annually handled over 1,000,000 passengers and twelve of the world's thirty busiest airports by passenger volume in 2014 were in the U.S.[Wikipedia]
#
# Air Travel is the most practical solution in the US, given the vastness of the country. However, this form of travel is not without problems. The entire system is both fascinating and disturbing, given the fact that overall, passengers were delayed 320 million hours in 2007 with an estimated deadweight economic loss of up to $41 billion[Wikipedia].
#
# We wish to depict how this complex system has evolved over the years and how, due to the delays, the system needs to be changed and improved.

# %% [markdown]
# ### Main Message

# %% [markdown]
# summarize the main message, outline the document, show preliminary visualizations you have already created, and show some sketches of visualizations that you want to create.
#
# Our goal is to visualize this complex yet streamlined system of air transportation in the United States. We will depict a time series storyboard of the airline industry.

# %% [markdown]
# ### Outlines

# %% [markdown]
#     1. Time Series Visualization of Evolution of Airports.
#     2. A Dorling Cartogram of the density of airports across US.
#     3. Time Series Visualization the onset of airline carriers across US.
#     4. Performance analysis of airlines.
#     5. Visualization of the factors that contribute to the delay.

# %% [markdown]
# ### Preliminary visualizations

# %% [markdown]
# We wish to show the evolution of airports across the US. Our current dataset has airline industry data spanning over 21 years, from the year 1987-2008. We will depict this with a US map which animates the presence of airports between these years.

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
img = mpimg.imread('/home/anusha/Downloads/DV-Final project/prelim_2.jpg')            #a picture of preliminary visualizations sketches
plt.imshow(img)

# %% [markdown]
# Note: Please find attached the image, as it is not rendered correctly here.

# %% [markdown]
# ###Background and related work:
#
# #####DataSet:
# http://stat-computing.org/dataexpo/2009/the-data.html
# This dataset is a collection of yearly data of 21 years starting from 1987 to 2008.
#
# https://developer.flightstats.com
# This is a SOAP based data scraping system/API we planned to retrive data for a given set of conditions.
#
# #####Related work
# We would like to share some interesting visualizations that appeared on some of the majors websites concerned with flight data but mostly concentrating on flight and carrier performances, based on flight timings. However,we mainly explore the evolution of air ways as a whole.
#
# http://projects.fivethirtyeight.com/flights/
#
# https://flowingdata.com/2009/09/10/3-in-depth-views-of-flight-delays-and-cancellations/
#
# http://thenextweb.com/shareables/2015/02/18/visualization-worlds-airline-flight-traffic-mesmerizing/
#
# #####Related Paper:
# http://www.usna.edu/Users/math/dphillip/jcgs-july.pdf
#
#
# #####Further Work:
#
# We would like to visualize an interactive module to find the best possible routes between two given airports and predict delays.
