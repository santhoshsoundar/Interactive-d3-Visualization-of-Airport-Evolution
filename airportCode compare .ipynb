# %% [markdown]
# ###Basically this is the initial ananlysis of data to find its nature and where their variance lie.
#
# #### We first wanted to know the number of unique airports and how they are varied across the timeline

# %%
import numpy as np
import pandas as pd

# %matplotlib inline


df = pd.read_csv('db_21/1987.csv', delimiter=',')
print len(df['Origin'])

# %%
import numpy as np
import pandas as pd

# %matplotlib inline


df = pd.read_csv('db_21/1987.csv', delimiter=',')
print len(df['Origin'])

# %%
uniqueAirport=[]            
for temp in df['Origin']:
    if temp not in uniqueAirport:
        uniqueAirport.append(temp)

print len(uniqueAirport)
# Out:
# 237

# %%
print uniqueAirport[:10]
# Out:
# ['SAN', 'SFO', 'BUR', 'OAK', 'LAX', 'PHX', 'SJC', 'LAS', 'SNA', 'SMF']

# %%
print len(df['Dest'])
# Out:
# 1311826

# %%
uniqueAirportDest=[]               
for temp in df['Dest']:
    if temp not in uniqueAirportDest:
        uniqueAirportDest.append(temp)

print len(uniqueAirportDest)
# Out:
# 237

# %%
df91 = pd.read_csv('db_21/1991.csv', delimiter=',')
print len(df91['Origin'])
# Out:
# 5076925

# %%
uniqueAirportDest91=[]               
for temp in df['Origin']:
    if temp not in uniqueAirportDest91:
        uniqueAirportDest91.append(temp)

print len(uniqueAirportDest91)
# Out:
# 237

# %%
#codes is a the file containing - [airport codes , lat , lon]

dfAll = pd.read_csv('codes.csv', delimiter=',')
print len(dfAll['locationID'])


x = dfAll['locationID'];
# Out:
# 13429

# %%
uniqueAirportCompare=[]                
for temp in x:
    if temp in uniqueAirportDest91:
        uniqueAirportCompare.append(temp)

print len(uniqueAirportCompare) 
print uniqueAirportCompare[:10]
# Out:
# 231
# ['ANC', 'BET', 'CDV', 'SCC', 'FAI', 'JNU', 'KTN', 'OTZ', 'OME', 'PSG']

# %%
#test is just trivial compared and can be ignored 
dft = pd.read_csv('test.csv', delimiter=',')
print len(dft['DEST'])
# Out:
# 135349

# %%
uniqueAirporttest=[]            
for temp in dft['DEST']:
    if temp not in uniqueAirport:
        uniqueAirporttest.append(temp)

print uniqueAirporttest[:10]
# Out:
# ['BOG', 'BRO', 'COU', 'GUA', 'KIN', 'MID', 'MKG', 'PAP', 'SAL', 'SAP']

# %%
uniqueAirportCompare=[]                
for temp in x:
    if temp in uniqueAirportDest91:
        uniqueAirportCompare.append(uniqueAirporttest)

print len(uniqueAirportCompare) 
print uniqueAirportCompare[:1]
# Out:
# 231
# [['BOG', 'BRO', 'COU', 'GUA', 'KIN', 'MID', 'MKG', 'PAP', 'SAL', 'SAP', 'SDQ', 'SFB', 'AEX', 'AEX', 'GUA', 'SFB', 'COU', 'AEX', 'AEX', 'CLL', 'AEX', 'SAL', 'AEX', 'AEX', 'AEX', 'AEX', 'GUA', 'MID', 'SAL', 'SAP', 'AEX', 'AEX', 'AEX', 'AEX', 'AEX', 'AEX', 'CFG', 'CMW', 'HAV', 'HOG', 'MID', 'NAS', 'PTK', 'SAL', 'SCU', 'SFB', 'SNU', 'PTK', 'NAS', 'AEX', 'AEX', 'AEX', 'GUA', 'LRD', 'BRO', 'GUA', 'KIN', 'SAL', 'SAP', 'SDQ', 'AEX', 'AEX', 'GUA', 'AEX', 'AEX', 'BRO', 'SAL', 'AEX', 'AEX', 'AEX', 'GUA', 'SAL', 'SAP', 'AEX', 'AEX', 'AEX', 'AEX', 'AEX', 'CMW', 'GGT', 'HAV', 'HOG', 'PAP', 'SAL', 'SCU', 'SDQ', 'SKB', 'AEX', 'AEX', 'AEX', 'SDQ', 'LRD', 'AEX', 'BOG', 'BRO', 'GUA', 'KIN', 'SAL', 'SAP', 'AEX', 'AEX', 'AEX', 'AEX', 'BRO', 'SAL', 'AEX', 'BRO', 'AEX', 'AEX', 'GUA', 'SAL', 'SAP', 'AEX', 'AEX', 'AEX', 'AEX', 'CMW', 'FPO', 'GGT', 'GUA', 'HAV', 'HOG', 'NAS', 'PAP', 'SCU', 'SNU', 'AEX', 'SFB', 'AEX', 'HAV', 'LRD', 'AFW', 'BOG', 'BRO', 'GUA', 'KIN', 'SAP', 'SDQ', 'JQF', 'AEX', 'AEX', 'GUA', 'AEX', 'SAL', 'AEX', 'AEX', 'AEX', 'AEX', 'GUA', 'SAL', 'SAP', 'AEX', 'AEX', 'AEX', 'AEX', 'AEX', 'AEX', 'BGI', 'BRO', 'CFG', 'CMW', 'ECP', 'FPO', 'GEO', 'HAV', 'HOG', 'HVA', 'NAS', 'PAP', 'SAL', 'SCU', 'SFB', 'SKB', 'AEX', 'AEX', 'GUA', 'LRD', 'EFD', 'DUB', 'MUC', 'DUB', 'MAN', 'ACK', 'ME3', 'RKD', 'TEB', 'HKS', 'POU', 'CBE', 'ISS', 'MD1', 'MMU', 'PDK', 'PWK', 'YTZ', 'BED', 'PSF', 'TEB', 'MMU', 'TEB', 'BED', 'ANU', 'AXA', 'AXA', 'NEV', 'NEV', 'SBH', 'SBH', 'SUA', 'SBH', 'MVY', 'FPR', 'TEB', 'YQB', 'TEB', 'ACK', 'CBE', 'EEN', 'HHH', 'MVL', 'PSF', 'YIP', 'MVL', 'SIG', 'SBH', 'ANU', 'AXA', 'EIS', 'MAZ', 'NEV', 'SBH', 'SBH', 'CEW', 'PUJ', 'SBH', 'SBH', 'AXA', 'UST', 'AXA', 'TEB', 'BMG', 'BED', 'OXC', 'PSF', 'HTO', 'ACK', 'BHB', 'MVL', 'OWD', 'QSO', 'SEG', 'SXM', 'YTZ', 'MVL', 'VQS', 'SBH', 'APA', 'BVY', 'PSF', 'OXC', 'BHB', 'MVL', 'ANU', 'AXA', 'AXA', 'EIS', 'MAZ', 'NEV', 'NEV', 'PUJ', 'SBH', 'SBH', 'SBH', 'SBH', '6B0', 'GON', 'SOP', 'TEB', 'BDR', 'MMU', 'OXC', 'TEB', 'ACK', 'ACY', 'ME3', 'MMU', 'TEB', 'MMU', 'FOK', 'TEB', 'SIG', 'FXE', 'ACK', 'ACK', 'ARB', 'BFT', 'CBE', 'GAI', 'LEB', 'MA4', 'MVY', 'SCE', 'YPD', 'ORL', 'ASH', 'SWF', 'TEB', 'NPT', 'DE3', 'ACK', 'BED', 'ACK', 'TEB', 'TEB', 'TEB', 'DNL', 'OWD', 'SIG', 'SBH', 'AXA', 'AXA', 'EIS', 'NEV', 'PLS', 'SBH', 'SBH', 'SBH', '6B0', 'ACK', 'EEN', 'NPT', 'TEB', 'MMU', 'TEB', 'BED', 'SEG', 'ACK', 'ACK', 'ME3', 'MMU', 'TEB', 'TTN', 'TEB', 'NHZ', 'FOK', 'CT1', 'ONH', 'HYA', 'ACK', 'ACK', 'ACY', 'BED', 'BID', 'CEU', 'HTO', 'HYA', 'LCI', 'MVY', 'MVY', 'NPT', 'OPF', 'PSM', 'RKD', 'TOP', 'VT1', 'YTM', 'YTZ', 'YUL', 'ZXU', 'FRG', 'VRB', 'MMU', 'APA', 'YIP', 'BED', 'ACK', 'BED', 'DXR', 'EWB', 'TEB', 'FOK', 'FOK', 'ACK', 'ACK', 'TEB', 'NPT', 'TEB', 'MTP', 'TEB', 'AXA', 'AXA', 'NEV', 'SBH', 'SBH', 'SBH', 'SXM', '6B0', 'ACK', 'ACY', 'LEB', 'MVY', 'NY7', 'PVC', 'SEG', 'ZXU', 'BED', 'YUL', 'JZI', 'BRO', 'CKB', 'MHK', 'SWO', 'FRG', 'YOW', 'YOW', 'BED', 'FRG', 'YOW', 'YYZ', 'GUA', 'GYY', 'BMG', 'BED', 'BED', 'FTW', 'CUN', 'CPS', 'FRG', 'BRO', 'AEX', 'YOW', 'BED', 'YVR', 'FRG', 'GUA', 'SAL', 'BED', 'YUL', 'XNA', 'BED', 'CKB', 'BRO', 'AEX', 'BRO', 'YYZ', 'CKB', 'BKL', 'YOW', 'AEX', 'BRO', 'BED', 'CKB', 'BRO', 'CMW', 'CUN', 'FPO', 'GYY', 'HAV', 'SFB', 'SNU', 'XNA', 'BED', 'BRO', 'YEG', 'PUW', 'AZA', 'BED', 'BKL', 'BRO', 'CKB', 'CPS', 'SWO', 'YEG', 'MHK', 'BED', 'CPS', 'YOW', 'BRO', 'YEG', 'AEX', 'BRO', 'FRG', 'FRG', 'FRG', 'BED', 'BRO', 'BED', 'CKB', 'MHK', 'CPS', 'FRG', 'YWG', 'BED', 'BRO', 'GUA', 'GYY', 'FRG', 'YOW', 'SWO', 'FRG', 'CKB', 'GUA', 'BED', 'CKB', 'YOW', 'YEG', 'BED', 'CKB', 'BRO', 'AEX', 'BRO', 'AEX', 'BRO', 'BED', 'YWG', 'BED', 'CMW', 'FPO', 'FRG', 'GYY', 'HAV', 'INT', 'SKB', 'BED', 'MHK', 'YYZ', 'PTK', 'YOW', 'YYZ', 'BED', 'PTK', 'SWO', 'YOW', 'YWG', 'BED', 'FRG', 'YOW', 'FRG', 'CKB', 'YOW', 'YWG', 'CKB', 'BED', 'CPS', 'BED', 'YXU', 'BRO', 'BED', 'MKC', 'BKL', 'YOW', 'BED', 'PUJ', 'XNA', 'AEX', 'GUA', 'GYY', 'BED', 'PUJ', 'BED', 'BED', 'PUJ', 'PUJ', 'CKB', 'YYC', 'PTK', 'YOW', 'BRO', 'GUA', 'BED', 'LUK', ' ...
